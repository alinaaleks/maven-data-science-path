# %%
import pandas as pd

# %%
pd.read_csv('course_offerings.csv') # in the same folder as JN - just write file name
# Out:
#    course_id                  course_name    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_csv('/Users/alinaaleks/Downloads/GitHub/maven-data-science-path/01-data-prep-eda/course_offerings.csv') # writing exact path
# Out:
#    course_id                  course_name    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_csv('data/course_offerings_below.csv') # relative path
# Out:
#    course_id                  course_name    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_csv('../data/course_offerings_above.csv') # relative path if the folder is higher
# Out:
#    course_id                  course_name    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_csv('course_offerings.csv') # (Shift + Tab => open settings)
# Out:
#    course_id                  course_name    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_csv('course_offerings.csv', sep=',') # specify separator
# Out:
#    course_id                  course_name    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_csv('course_offerings.csv', sep=',', header=None)
# Out:
#            0                            1             2
# 0  course_id                  course_name    instructor
# 1        101              Intro to Python  Chris Bruehl
# 2        102                 Intro to SQL   John Pauler
# 3        201    Exploratory Data Analysis    Alice Zhao
# 4        301                   Algorithms  Chris Bruehl
# 5        331  Natural Language Processing    Alice Zhao

# %%
pd.read_excel('Course Offerings.xlsx', sheet_name=1) # sheets start count from 0
# Out:
#    Course ID                  Course Name    Instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
import sqlite3 # connect to SQL DB

# %%
conn = sqlite3.connect('../data/maven.db')

# %%
pd.read_sql('SELECT * FROM courses', conn)
# Out:
#    course_id                       course    instructor
# 0        101              Intro to Python  Chris Bruehl
# 1        102                 Intro to SQL   John Pauler
# 2        201    Exploratory Data Analysis    Alice Zhao
# 3        301                   Algorithms  Chris Bruehl
# 4        331  Natural Language Processing    Alice Zhao

# %%
pd.read_sql('SELECT * FROM courses WHERE course_id=101', conn)
# Out:
#    course_id           course    instructor
# 0        101  Intro to Python  Chris Bruehl

# %%
pd.read_sql('SELECT * FROM courses WHERE course_id LIKE "1%"', conn)
# Out:
#    course_id           course    instructor
# 0        101  Intro to Python  Chris Bruehl
# 1        102     Intro to SQL   John Pauler

# %% [markdown]
# #### install a db driver (pip install or conda install):

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.5 MB 3.4 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/16.5 MB 2.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.6/16.5 MB 2.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.1/16.5 MB 2.8 MB/s eta 0:00:06
#    ------ --------------------------------- 2.9/16.5 MB 2.8 MB/s eta 0:00:05
#    -------- ------------------------------- 3.7/16.5 MB 2.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/16.5 MB 3.0 MB/s eta 0:00:05
#    ------------ --------------------------- 5.0/16.5 MB 3.0 MB/s eta 0:00:04
#    ------------- -------------------------- 5.8/16.5 MB 3.1 MB/s eta 0:00:04
#    --------------- ------------------------ 6.6/16.5 MB 3.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 7.3/16.5 MB 3.2 MB/s eta 0:00:03
# ...

# %%
import mysql.connector

# %%
# MySQL connection
conn = mysql.connector.connect(host='localhost',
                               database='mavenmovies',
                               user='root',
                               password='password') # insert my pass here
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\miniconda3\envs\maven-ds\Lib\site-packages\mysql\connector\connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[49], line 2
#       1 # MySQL connection
# ----> 2 conn = mysql.connector.connect(host='localhost',
#       3                                database='mavenmovies',
#       4                                user='root',
#       5                                password='password') # insert my pass here
#
# ...

# %%
pd.read_sql('SELECT * FROM city', conn)
# Out:
# C:\Users\alinaaleks\AppData\Local\Temp\ipykernel_8484\2964174485.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('SELECT * FROM city', conn)
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 04:45:25
# 1          2                Abha          82 2006-02-15 04:45:25
# 2          3           Abu Dhabi         101 2006-02-15 04:45:25
# 3          4                Acua          60 2006-02-15 04:45:25
# 4          5               Adana          97 2006-02-15 04:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 04:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 04:45:25
# 597      598         Zhezqazghan          51 2006-02-15 04:45:25
# ...

# %%
import psycopg2

# %%
# PostgreSQL connection
conn = psycopg2.connect(host='localhost',
                        port=5432,
                        database='parchAndPosey',
                        user='postgres',
                        password='2951620') # insert my pass here

# %%
pd.read_sql('SELECT * FROM accounts', conn)
# Out:
# C:\Users\alinaaleks\AppData\Local\Temp\ipykernel_8484\2073245136.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('SELECT * FROM accounts', conn)
#        id                name                    website        lat  \
# 0    1001             Walmart            www.walmart.com  40.238496
# 1    1011         Exxon Mobil         www.exxonmobil.com  41.169156
# 2    1021               Apple              www.apple.com  42.290495
# 3    1031  Berkshire Hathaway  www.berkshirehathaway.com  40.949021
# 4    1041            McKesson           www.mckesson.com  42.217093
# ..    ...                 ...                        ...        ...
# 346  4461                 KKR                www.kkr.com  45.545353
# 347  4471               Oneok              www.oneok.com  45.513513
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:password@localhost:5432/dvdrental')

# %%
df = pd.read_sql('SELECT * FROM actor', engine)
print(df)
# Out:
#      actor_id first_name     last_name             last_update
# 0           1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1           2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2           3         Ed         Chase 2013-05-26 14:47:57.620
# 3           4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4           5     Johnny  Lollobrigida 2013-05-26 14:47:57.620
# ..        ...        ...           ...                     ...
# 195       196       Bela        Walken 2013-05-26 14:47:57.620
# 196       197      Reese          West 2013-05-26 14:47:57.620
# 197       198       Mary        Keitel 2013-05-26 14:47:57.620
# 198       199      Julia       Fawcett 2013-05-26 14:47:57.620
# 199       200      Thora        Temple 2013-05-26 14:47:57.620
#
# [200 rows x 4 columns]

# %%
df
# Out:
#      actor_id first_name     last_name             last_update
# 0           1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1           2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2           3         Ed         Chase 2013-05-26 14:47:57.620
# 3           4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4           5     Johnny  Lollobrigida 2013-05-26 14:47:57.620
# ..        ...        ...           ...                     ...
# 195       196       Bela        Walken 2013-05-26 14:47:57.620
# 196       197      Reese          West 2013-05-26 14:47:57.620
# 197       198       Mary        Keitel 2013-05-26 14:47:57.620
# 198       199      Julia       Fawcett 2013-05-26 14:47:57.620
# 199       200      Thora        Temple 2013-05-26 14:47:57.620
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1         2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2         3         Ed         Chase 2013-05-26 14:47:57.620
# 3         4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4         5     Johnny  Lollobrigida 2013-05-26 14:47:57.620

# %%
df.head(2)
# Out:
#    actor_id first_name last_name             last_update
# 0         1   Penelope   Guiness 2013-05-26 14:47:57.620
# 1         2       Nick  Wahlberg 2013-05-26 14:47:57.620

# %%
df.tail(2)
# Out:
#      actor_id first_name last_name             last_update
# 198       199      Julia   Fawcett 2013-05-26 14:47:57.620
# 199       200      Thora    Temple 2013-05-26 14:47:57.620

# %%
df.shape
# Out:
# (200, 4)

# %%
df.count()
# Out:
# actor_id       200
# first_name     200
# last_name      200
# last_update    200
# dtype: int64

# %%
df.describe()
# Out:
#          actor_id                 last_update
# count  200.000000                         200
# mean   100.500000  2013-05-26 14:47:57.620000
# min      1.000000  2013-05-26 14:47:57.620000
# 25%     50.750000  2013-05-26 14:47:57.620000
# 50%    100.500000  2013-05-26 14:47:57.620000
# 75%    150.250000  2013-05-26 14:47:57.620000
# max    200.000000  2013-05-26 14:47:57.620000
# std     57.879185                         NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    str
#  2   last_name    200 non-null    str
#  3   last_update  200 non-null    datetime64[us]
# dtypes: datetime64[us](1), int64(1), str(2)
# memory usage: 6.4 KB
