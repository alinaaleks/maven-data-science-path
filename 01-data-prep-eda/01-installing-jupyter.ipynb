# %% [markdown]
# # Markdown
#
# ### Subtitle
#
# * headers use # from 1 to 6
# * bullets: use *, numbers
# * *bold**, *italic*, ***bold AND italic***
# * links [name](link)
# * code insert - ise backtick `conda activate maven-ds`

# %% [markdown]
# ### Helpful resources
#
# 1. **Stack Overflow**
#
# 2. **Official Python Documentation** - great **cheat sheet** for library and language references
# ***https://docs.python.org/3/***
#
# 3. **Python** and **Analytics Blogs** like ***https://towardsdatascience.com/***

# %%
# Part 1: Data Prep & Exploratory Data Analysis

# %%
2+3
# Out:
# 5
